# %%
from main_script import *
from training import train_model

epochs=5 
train_model(model, criterion, optimizer, trainloader, epochs)
# Out:
# Training loss: 1.265893
# Training loss: 0.600162
# Training loss: 0.510708
# Training loss: 0.466438
# Training loss: 0.440415
# [1.265892773930198,
#  0.6001620212279911,
#  0.510708235537828,
#  0.4664378797988902,
#  0.4404154415768601]

# %%
from view import plot
import ipywidgets as widgets
from IPython.display import display, clear_output

classes = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat","Sandal", "Shirt", "Sneaker", "Bag", "Ankle Boot"]
plot(model, testloader, classes)
# Out:
# Button(description='Select New Image', style=ButtonStyle())
